# %%
import pandas as pd
import numpy as np
import math
from ast import literal_eval

# %% [markdown]
# # Read file final.csv

# %%
df = pd.read_csv('data_hcm_final.csv')
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # String categories to npArray

# %%
for i in range(df['categories'].size):
    if(df['categories'][i] == df['categories'][i]):
        df.at[i, 'categories'] = np.array(literal_eval(df['categories'][i]))

# %% [markdown]
# # .explode

# %%
df = df.explode('categories')

# %%
df.categories.unique()
# Out:
# array([nan, 'Nhà hàng', 'Sang trọng', 'Tiệc cưới/Hội nghị',
#        'Café/Dessert', 'Quán ăn', 'Buffet', 'Ăn vặt/vỉa hè', 'Tiệm bánh',
#        'Ăn chay', 'Shop Online', 'Bar/Pub', 'Beer club', 'Tiệc tận nơi',
#        'Giao cơm văn phòng', 'Quán nhậu', 'Mua sắm Online',
#        'Shop/Cửa hàng', 'Khu Ẩm Thực', 'Vật nuôi', 'Chợ', 'Spa/Massage',
#        'Karaoke', 'Sân khấu', 'Khu chơi Game', 'Siêu thị',
#        'Thăm quan & chụp ảnh', 'Billiards', 'Thể dục thể thao',
#        'Đại Học & Cao Đẳng', 'Hoa cưới - Shop hoa', 'Cửa Hàng - Phụ Kiện',
#        'Shop hóa mỹ phẩm', 'Rạp chiếu phim'], dtype=object)

# %% [markdown]
# # Filter by categories

# %%
NhaHang_df = df[df['categories'] == 'Nhà hàng']
QuanAn_df = df[df['categories'] == 'Quán ăn']
AnVatViaHe_df = df[df['categories'] == 'Ăn vặt/vỉa hè']

# %%
NhaHang_df = NhaHang_df[NhaHang_df['avg_price'] != 'nan']

# %% [markdown]
# # Filter by district

# %%
df.District.unique()
# Out:
# array(['Quận 1', 'Tp. Thủ Đức', 'Quận 10', 'Quận 2', 'Quận 7', 'Quận 5',
#        'Quận 8', 'Huyện Bình Chánh', 'Quận Tân Phú', 'Quận Bình Tân',
#        'Quận Bình Thạnh', 'Quận Phú Nhuận', 'Quận Gò Vấp', 'Quận 11',
#        'Quận Tân Bình', 'Huyện Nhà Bè', 'Quận 3', 'Quận 4', 'Quận 6',
#        'Quận 9', 'Quận 12', 'Huyện Hóc Môn', 'Huyện Củ Chi',
#        'Huyện Cần Giờ'], dtype=object)

# %% [markdown]
# ### Nhà Hàng

# %%
NhaHang_Q1_df = NhaHang_df[NhaHang_df['District'] == 'Quận 1']
NhaHang_Q2_df = NhaHang_df[NhaHang_df['District'] == 'Quận 2']
NhaHang_Q3_df = NhaHang_df[NhaHang_df['District'] == 'Quận 3']
NhaHang_Q4_df = NhaHang_df[NhaHang_df['District'] == 'Quận 4']
NhaHang_Q5_df = NhaHang_df[NhaHang_df['District'] == 'Quận 5']
NhaHang_Q6_df = NhaHang_df[NhaHang_df['District'] == 'Quận 6']
NhaHang_Q7_df = NhaHang_df[NhaHang_df['District'] == 'Quận 7']
NhaHang_Q8_df = NhaHang_df[NhaHang_df['District'] == 'Quận 8']
NhaHang_Q9_df = NhaHang_df[NhaHang_df['District'] == 'Quận 9']
NhaHang_Q10_df = NhaHang_df[NhaHang_df['District'] == 'Quận 10']
NhaHang_Q11_df = NhaHang_df[NhaHang_df['District'] == 'Quận 11']
NhaHang_Q12_df = NhaHang_df[NhaHang_df['District'] == 'Quận 12']
NhaHang_TPTD_df = NhaHang_df[NhaHang_df['District'] == 'Tp. Thủ Đức']
NhaHang_HBC_df = NhaHang_df[NhaHang_df['District'] == 'Huyện Bình Chánh']
NhaHang_QTP_df = NhaHang_df[NhaHang_df['District'] == 'Quận Tân Phú']
NhaHang_QBTan_df = NhaHang_df[NhaHang_df['District'] == 'Quận Bình Tân']
NhaHang_QBThanh_df = NhaHang_df[NhaHang_df['District'] == 'Quận Bình Thạnh']
NhaHang_QPN_df = NhaHang_df[NhaHang_df['District'] == 'Quận Phú Nhuận']
NhaHang_QGV_df = NhaHang_df[NhaHang_df['District'] == 'Quận Gò Vấp']
NhaHang_QTB_df = NhaHang_df[NhaHang_df['District'] == 'Quận Tân Bình']
NhaHang_HNB_df = NhaHang_df[NhaHang_df['District'] == 'Huyện Nhà Bè']
NhaHang_HHM_df = NhaHang_df[NhaHang_df['District'] == 'Huyện Hóc Môn']
NhaHang_HCC_df = NhaHang_df[NhaHang_df['District'] == 'Huyện Củ Chi']
NhaHang_HCG_df = NhaHang_df[NhaHang_df['District'] == 'Huyện Cần Giờ']

# %% [markdown]
# ### Quán ăn

# %%
QuanAn_Q1_df = QuanAn_df[QuanAn_df['District'] == 'Quận 1']
QuanAn_Q2_df = QuanAn_df[QuanAn_df['District'] == 'Quận 2']
QuanAn_Q3_df = QuanAn_df[QuanAn_df['District'] == 'Quận 3']
QuanAn_Q4_df = QuanAn_df[QuanAn_df['District'] == 'Quận 4']
QuanAn_Q5_df = QuanAn_df[QuanAn_df['District'] == 'Quận 5']
QuanAn_Q6_df = QuanAn_df[QuanAn_df['District'] == 'Quận 6']
QuanAn_Q7_df = QuanAn_df[QuanAn_df['District'] == 'Quận 7']
QuanAn_Q8_df = QuanAn_df[QuanAn_df['District'] == 'Quận 8']
QuanAn_Q9_df = QuanAn_df[QuanAn_df['District'] == 'Quận 9']
QuanAn_Q10_df = QuanAn_df[QuanAn_df['District'] == 'Quận 10']
QuanAn_Q11_df = QuanAn_df[QuanAn_df['District'] == 'Quận 11']
QuanAn_Q12_df = QuanAn_df[QuanAn_df['District'] == 'Quận 12']
QuanAn_TPTD_df = QuanAn_df[QuanAn_df['District'] == 'Tp. Thủ Đức']
QuanAn_HBC_df = QuanAn_df[QuanAn_df['District'] == 'Huyện Bình Chánh']
QuanAn_QTP_df = QuanAn_df[QuanAn_df['District'] == 'Quận Tân Phú']
QuanAn_QBTan_df = QuanAn_df[QuanAn_df['District'] == 'Quận Bình Tân']
QuanAn_QBThanh_df = QuanAn_df[QuanAn_df['District'] == 'Quận Bình Thạnh']
QuanAn_QPN_df = QuanAn_df[QuanAn_df['District'] == 'Quận Phú Nhuận']
QuanAn_QGV_df = QuanAn_df[QuanAn_df['District'] == 'Quận Gò Vấp']
QuanAn_QTB_df = QuanAn_df[QuanAn_df['District'] == 'Quận Tân Bình']
QuanAn_HNB_df = QuanAn_df[QuanAn_df['District'] == 'Huyện Nhà Bè']
QuanAn_HHM_df = QuanAn_df[QuanAn_df['District'] == 'Huyện Hóc Môn']
QuanAn_HCC_df = QuanAn_df[QuanAn_df['District'] == 'Huyện Củ Chi']
QuanAn_HCG_df = QuanAn_df[QuanAn_df['District'] == 'Huyện Cần Giờ']

# %% [markdown]
# ### Ăn vặt vĩa hè

# %%
AnVatViaHe_Q1_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 1']
AnVatViaHe_Q2_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 2']
AnVatViaHe_Q3_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 3']
AnVatViaHe_Q4_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 4']
AnVatViaHe_Q5_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 5']
AnVatViaHe_Q6_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 6']
AnVatViaHe_Q7_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 7']
AnVatViaHe_Q8_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 8']
AnVatViaHe_Q9_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 9']
AnVatViaHe_Q10_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 10']
AnVatViaHe_Q11_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 11']
AnVatViaHe_Q12_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận 12']
AnVatViaHe_TPTD_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Tp. Thủ Đức']
AnVatViaHe_HBC_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Huyện Bình Chánh']
AnVatViaHe_QTP_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận Tân Phú']
AnVatViaHe_QBTan_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận Bình Tân']
AnVatViaHe_QBThanh_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận Bình Thạnh']
AnVatViaHe_QPN_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận Phú Nhuận']
AnVatViaHe_QGV_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận Gò Vấp']
AnVatViaHe_QTB_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Quận Tân Bình']
AnVatViaHe_HNB_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Huyện Nhà Bè']
AnVatViaHe_HHM_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Huyện Hóc Môn']
AnVatViaHe_HCC_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Huyện Củ Chi']
AnVatViaHe_HCG_df = AnVatViaHe_df[AnVatViaHe_df['District'] == 'Huyện Cần Giờ']

# %% [markdown]
# # Filter within 1st and 3rd quartile

# %% [markdown]
# ### Nhà hàng

# %%
if NhaHang_Q1_df['avg_price'].size > 0:
    low, high = NhaHang_Q1_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q1_df = NhaHang_Q1_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_Q2_df['avg_price'].size > 0:
    low, high = NhaHang_Q2_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q2_df = NhaHang_Q2_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_Q3_df['avg_price'].size > 0:
    low, high = NhaHang_Q3_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q3_df = NhaHang_Q3_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_Q4_df['avg_price'].size > 0:
    low, high = NhaHang_Q4_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q4_df = NhaHang_Q4_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_Q5_df['avg_price'].size > 0:
    low, high = NhaHang_Q5_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q5_df = NhaHang_Q5_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_Q6_df['avg_price'].size > 0:
    low, high = NhaHang_Q6_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q6_df = NhaHang_Q6_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_Q7_df['avg_price'].size > 0:
    low, high = NhaHang_Q7_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q7_df = NhaHang_Q7_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_Q8_df['avg_price'].size > 0:
    low, high = NhaHang_Q8_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q8_df = NhaHang_Q8_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_Q9_df['avg_price'].size > 0:
    low, high = NhaHang_Q9_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q9_df = NhaHang_Q9_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_Q10_df['avg_price'].size > 0:
    low, high = NhaHang_Q10_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q10_df = NhaHang_Q10_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_Q11_df['avg_price'].size > 0:
    low, high = NhaHang_Q11_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q11_df = NhaHang_Q11_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_Q12_df['avg_price'].size > 0:
    low, high = NhaHang_Q12_df.avg_price.quantile([0.25,0.75])
    NhaHang_Q12_df = NhaHang_Q12_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_TPTD_df['avg_price'].size > 0:
    low, high = NhaHang_TPTD_df.avg_price.quantile([0.25,0.75])
    NhaHang_TPTD_df = NhaHang_TPTD_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_HBC_df['avg_price'].size > 0:
    low, high = NhaHang_HBC_df.avg_price.quantile([0.25,0.75])
    NhaHang_HBC_df = NhaHang_HBC_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_QTP_df['avg_price'].size > 0:
    low, high = NhaHang_QTP_df.avg_price.quantile([0.25,0.75])
    NhaHang_QTP_df = NhaHang_QTP_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_QBTan_df['avg_price'].size > 0:
    low, high = NhaHang_QBTan_df.avg_price.quantile([0.25,0.75])
    NhaHang_QBTan_df = NhaHang_QBTan_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_QBThanh_df['avg_price'].size > 0:
    low, high = NhaHang_QBThanh_df.avg_price.quantile([0.25,0.75])
    NhaHang_QBThanh_df = NhaHang_QBThanh_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_QPN_df['avg_price'].size > 0:
    low, high = NhaHang_QPN_df.avg_price.quantile([0.25,0.75])
    NhaHang_QPN_df = NhaHang_QPN_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_QGV_df['avg_price'].size > 0:
    low, high = NhaHang_QGV_df.avg_price.quantile([0.25,0.75])
    NhaHang_QGV_df = NhaHang_QGV_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_QTB_df['avg_price'].size > 0:
    low, high = NhaHang_QTB_df.avg_price.quantile([0.25,0.75])
    NhaHang_QTB_df = NhaHang_QTB_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_HNB_df['avg_price'].size > 0:
    low, high = NhaHang_HNB_df.avg_price.quantile([0.25,0.75])
    NhaHang_HNB_df = NhaHang_HNB_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_HHM_df['avg_price'].size > 0:
    low, high = NhaHang_HHM_df.avg_price.quantile([0.25,0.75])
    NhaHang_HHM_df = NhaHang_HHM_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_HCC_df['avg_price'].size > 0:
    low, high = NhaHang_HCC_df.avg_price.quantile([0.25,0.75])
    NhaHang_HCC_df = NhaHang_HCC_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if NhaHang_HCG_df['avg_price'].size > 0:
    low, high = NhaHang_HCG_df.avg_price.quantile([0.25,0.75])
    NhaHang_QCG_df = NhaHang_HCG_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

# %% [markdown]
# ### Quán ăn

# %%
if QuanAn_Q1_df['avg_price'].size > 0:
    low, high = QuanAn_Q1_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q1_df = QuanAn_Q1_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_Q2_df['avg_price'].size > 0:
    low, high = QuanAn_Q2_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q2_df = QuanAn_Q2_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_Q3_df['avg_price'].size > 0:
    low, high = QuanAn_Q3_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q3_df = QuanAn_Q3_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_Q4_df['avg_price'].size > 0:
    low, high = QuanAn_Q4_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q4_df = QuanAn_Q4_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_Q5_df['avg_price'].size > 0:
    low, high = QuanAn_Q5_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q5_df = QuanAn_Q5_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_Q6_df['avg_price'].size > 0:
    low, high = QuanAn_Q6_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q6_df = QuanAn_Q6_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_Q7_df['avg_price'].size > 0:
    low, high = QuanAn_Q7_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q7_df = QuanAn_Q7_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_Q8_df['avg_price'].size > 0:
    low, high = QuanAn_Q8_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q8_df = QuanAn_Q8_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_Q9_df['avg_price'].size > 0:
    low, high = QuanAn_Q9_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q9_df = QuanAn_Q9_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_Q10_df['avg_price'].size > 0:
    low, high = QuanAn_Q10_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q10_df = QuanAn_Q10_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_Q11_df['avg_price'].size > 0:
    low, high = QuanAn_Q11_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q11_df = QuanAn_Q11_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_Q12_df['avg_price'].size > 0:
    low, high = QuanAn_Q12_df.avg_price.quantile([0.25,0.75])
    QuanAn_Q12_df = QuanAn_Q12_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_TPTD_df['avg_price'].size > 0:
    low, high = QuanAn_TPTD_df.avg_price.quantile([0.25,0.75])
    QuanAn_TPTD_df = QuanAn_TPTD_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_HBC_df['avg_price'].size > 0:
    low, high = QuanAn_HBC_df.avg_price.quantile([0.25,0.75])
    QuanAn_HBC_df = QuanAn_HBC_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_QTP_df['avg_price'].size > 0:
    low, high = QuanAn_QTP_df.avg_price.quantile([0.25,0.75])
    QuanAn_QTP_df = QuanAn_QTP_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_QBTan_df['avg_price'].size > 0:
    low, high = QuanAn_QBTan_df.avg_price.quantile([0.25,0.75])
    QuanAn_QBTan_df = QuanAn_QBTan_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_QBThanh_df['avg_price'].size > 0:
    low, high = QuanAn_QBThanh_df.avg_price.quantile([0.25,0.75])
    QuanAn_QBThanh_df = QuanAn_QBThanh_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_QPN_df['avg_price'].size > 0:
    low, high = QuanAn_QPN_df.avg_price.quantile([0.25,0.75])
    QuanAn_QPN_df = QuanAn_QPN_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_QGV_df['avg_price'].size > 0:
    low, high = QuanAn_QGV_df.avg_price.quantile([0.25,0.75])
    QuanAn_QGV_df = QuanAn_QGV_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_QTB_df['avg_price'].size > 0:
    low, high = QuanAn_QTB_df.avg_price.quantile([0.25,0.75])
    QuanAn_QTB_df = QuanAn_QTB_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_HNB_df['avg_price'].size > 0:
    low, high = QuanAn_HNB_df.avg_price.quantile([0.25,0.75])
    QuanAn_HNB_df = QuanAn_HNB_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_HHM_df['avg_price'].size > 0:
    low, high = QuanAn_HHM_df.avg_price.quantile([0.25,0.75])
    QuanAn_HHM_df = QuanAn_HHM_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_HCC_df['avg_price'].size > 0:
    low, high = QuanAn_HCC_df.avg_price.quantile([0.25,0.75])
    QuanAn_HCC_df = QuanAn_HCC_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if QuanAn_HCG_df['avg_price'].size > 0:
    low, high = QuanAn_HCG_df.avg_price.quantile([0.25,0.75])
    QuanAn_QCG_df = QuanAn_HCG_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

# %% [markdown]
# ### Ăn vặt vĩa hè

# %%
if AnVatViaHe_Q1_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q1_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q1_df = AnVatViaHe_Q1_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_Q2_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q2_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q2_df = AnVatViaHe_Q2_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_Q3_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q3_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q3_df = AnVatViaHe_Q3_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_Q4_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q4_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q4_df = AnVatViaHe_Q4_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_Q5_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q5_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q5_df = AnVatViaHe_Q5_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_Q6_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q6_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q6_df = AnVatViaHe_Q6_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_Q7_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q7_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q7_df = AnVatViaHe_Q7_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_Q8_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q8_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q8_df = AnVatViaHe_Q8_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_Q9_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q9_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q9_df = AnVatViaHe_Q9_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_Q10_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q10_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q10_df = AnVatViaHe_Q10_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_Q11_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q11_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q11_df = AnVatViaHe_Q11_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_Q12_df['avg_price'].size > 0:
    low, high = AnVatViaHe_Q12_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_Q12_df = AnVatViaHe_Q12_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_TPTD_df['avg_price'].size > 0:
    low, high = AnVatViaHe_TPTD_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_TPTD_df = AnVatViaHe_TPTD_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_HBC_df['avg_price'].size > 0:
    low, high = AnVatViaHe_HBC_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_HBC_df = AnVatViaHe_HBC_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_QTP_df['avg_price'].size > 0:
    low, high = AnVatViaHe_QTP_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_QTP_df = AnVatViaHe_QTP_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_QBTan_df['avg_price'].size > 0:
    low, high = AnVatViaHe_QBTan_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_QBTan_df = AnVatViaHe_QBTan_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_QBThanh_df['avg_price'].size > 0:
    low, high = AnVatViaHe_QBThanh_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_QBThanh_df = AnVatViaHe_QBThanh_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_QPN_df['avg_price'].size > 0:
    low, high = AnVatViaHe_QPN_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_QPN_df = AnVatViaHe_QPN_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_QGV_df['avg_price'].size > 0:
    low, high = AnVatViaHe_QGV_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_QGV_df = AnVatViaHe_QGV_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_QTB_df['avg_price'].size > 0:
    low, high = AnVatViaHe_QTB_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_QTB_df = AnVatViaHe_QTB_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_HNB_df['avg_price'].size > 0:
    low, high = AnVatViaHe_HNB_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_HNB_df = AnVatViaHe_HNB_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_HHM_df['avg_price'].size > 0:
    low, high = AnVatViaHe_HHM_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_HHM_df = AnVatViaHe_HHM_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_HCC_df['avg_price'].size > 0:
    low, high = AnVatViaHe_HCC_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_HCC_df = AnVatViaHe_HCC_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

if AnVatViaHe_HCG_df['avg_price'].size > 0:
    low, high = AnVatViaHe_HCG_df.avg_price.quantile([0.25,0.75])
    AnVatViaHe_QCG_df = AnVatViaHe_HCG_df.query('{low}<avg_price<{high}'.format(low=low,high=high))

# %% [markdown]
# # DV avg_prive - District

# %%
import matplotlib.pyplot as plt

# %%
column = list(df.District.unique())

# %% [markdown]
# ### Nhà hàng

# %%
values = np.array([NhaHang_Q1_df['avg_price'].mean(), NhaHang_TPTD_df['avg_price'].mean(), 
        NhaHang_Q10_df['avg_price'].mean(), NhaHang_Q2_df['avg_price'].mean(),
        NhaHang_Q7_df['avg_price'].mean(), NhaHang_Q5_df['avg_price'].mean(),
        NhaHang_Q8_df['avg_price'].mean(), NhaHang_HBC_df['avg_price'].mean(),
        NhaHang_QTP_df['avg_price'].mean(), NhaHang_QBTan_df['avg_price'].mean(),
        NhaHang_QBThanh_df['avg_price'].mean(), NhaHang_QPN_df['avg_price'].mean(),
        NhaHang_QGV_df['avg_price'].mean(), NhaHang_Q11_df['avg_price'].mean(),
        NhaHang_QTB_df['avg_price'].mean(), NhaHang_HNB_df['avg_price'].mean(),
        NhaHang_Q3_df['avg_price'].mean(), NhaHang_Q4_df['avg_price'].mean(),
        NhaHang_Q6_df['avg_price'].mean(), NhaHang_Q9_df['avg_price'].mean(),
        NhaHang_Q12_df['avg_price'].mean(), NhaHang_HHM_df['avg_price'].mean(),
        NhaHang_HCC_df['avg_price'].mean(), NhaHang_HCG_df['avg_price'].mean()])

# %%
d = {'District': column, 'avgPrice': values}
NhaHang_DV_df = pd.DataFrame(data=d)
NhaHang_DV_df = NhaHang_DV_df.sort_values(by='avgPrice')


fig = plt.figure(figsize = (20, 15))
 
# creating the bar plot
plt.rcParams.update({'font.size': 22})
plt.grid(True, color = "grey", linewidth = "0.3")
plt.barh(NhaHang_DV_df['District'], NhaHang_DV_df['avgPrice'])
 
plt.xlabel("Giá trung Bình (VNĐ)")
plt.ylabel("Quận")
plt.title("Giá trung bình của nhà hàng ở các quận thuộc TP. Hồ Chí Minh")
plt.show()

# %% [markdown]
# ### Quán ăn

# %%
values = np.array([QuanAn_Q1_df['avg_price'].mean(), QuanAn_TPTD_df['avg_price'].mean(), 
        QuanAn_Q10_df['avg_price'].mean(), QuanAn_Q2_df['avg_price'].mean(),
        QuanAn_Q7_df['avg_price'].mean(), QuanAn_Q5_df['avg_price'].mean(),
        QuanAn_Q8_df['avg_price'].mean(), QuanAn_HBC_df['avg_price'].mean(),
        QuanAn_QTP_df['avg_price'].mean(), QuanAn_QBTan_df['avg_price'].mean(),
        QuanAn_QBThanh_df['avg_price'].mean(), QuanAn_QPN_df['avg_price'].mean(),
        QuanAn_QGV_df['avg_price'].mean(), QuanAn_Q11_df['avg_price'].mean(),
        QuanAn_QTB_df['avg_price'].mean(), QuanAn_HNB_df['avg_price'].mean(),
        QuanAn_Q3_df['avg_price'].mean(), QuanAn_Q4_df['avg_price'].mean(),
        QuanAn_Q6_df['avg_price'].mean(), QuanAn_Q9_df['avg_price'].mean(),
        QuanAn_Q12_df['avg_price'].mean(), QuanAn_HHM_df['avg_price'].mean(),
        QuanAn_HCC_df['avg_price'].mean(), QuanAn_HCG_df['avg_price'].mean()])

# %%
d = {'District': column, 'avgPrice': values}
QuanAn_DV_df = pd.DataFrame(data=d)
QuanAn_DV_df = QuanAn_DV_df.sort_values(by='avgPrice')


fig = plt.figure(figsize = (20, 15))
 
# creating the bar plot
plt.rcParams.update({'font.size': 22})
plt.grid(True, color = "grey", linewidth = "0.3")
plt.barh(QuanAn_DV_df['District'], QuanAn_DV_df['avgPrice'])
 
plt.xlabel("Giá trung Bình (VNĐ)")
plt.ylabel("Quận")
plt.title("Giá trung bình của quán ăn ở các quận thuộc TP. Hồ Chí Minh")
plt.show()

# %% [markdown]
# ### Ăn vặt vĩa hè

# %%
values = np.array([AnVatViaHe_Q1_df['avg_price'].mean(), AnVatViaHe_TPTD_df['avg_price'].mean(), 
        AnVatViaHe_Q10_df['avg_price'].mean(), AnVatViaHe_Q2_df['avg_price'].mean(),
        AnVatViaHe_Q7_df['avg_price'].mean(), AnVatViaHe_Q5_df['avg_price'].mean(),
        AnVatViaHe_Q8_df['avg_price'].mean(), AnVatViaHe_HBC_df['avg_price'].mean(),
        AnVatViaHe_QTP_df['avg_price'].mean(), AnVatViaHe_QBTan_df['avg_price'].mean(),
        AnVatViaHe_QBThanh_df['avg_price'].mean(), AnVatViaHe_QPN_df['avg_price'].mean(),
        AnVatViaHe_QGV_df['avg_price'].mean(), AnVatViaHe_Q11_df['avg_price'].mean(),
        AnVatViaHe_QTB_df['avg_price'].mean(), AnVatViaHe_HNB_df['avg_price'].mean(),
        AnVatViaHe_Q3_df['avg_price'].mean(), AnVatViaHe_Q4_df['avg_price'].mean(),
        AnVatViaHe_Q6_df['avg_price'].mean(), AnVatViaHe_Q9_df['avg_price'].mean(),
        AnVatViaHe_Q12_df['avg_price'].mean(), AnVatViaHe_HHM_df['avg_price'].mean(),
        AnVatViaHe_HCC_df['avg_price'].mean(), AnVatViaHe_HCG_df['avg_price'].mean()])

# %%
d = {'District': column, 'avgPrice': values}
AnVatViaHe_DV_df = pd.DataFrame(data=d)
AnVatViaHe_DV_df = AnVatViaHe_DV_df.sort_values(by='avgPrice')


fig = plt.figure(figsize = (20, 15))
 
# creating the bar plot
plt.rcParams.update({'font.size': 22})
plt.grid(True, color = "grey", linewidth = "0.3")
plt.barh(AnVatViaHe_DV_df['District'], AnVatViaHe_DV_df['avgPrice'])
 
plt.xlabel("Giá trung Bình (VNĐ)")
plt.ylabel("Quận")
plt.title("Giá trung bình của quán ăn vĩa hè ở các quận thuộc TP. Hồ Chí Minh")
plt.show()
